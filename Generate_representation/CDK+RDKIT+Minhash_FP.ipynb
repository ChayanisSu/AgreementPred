# %% [markdown]
# The codes implemeted here are derived from the following sources:
# - Boldini D, Ballabio D, Consonni V, Todeschini R, Grisoni F, Sieber SA. Effectiveness of molecular fingerprints for exploring the chemical space of natural products. J Cheminform. 2024;16(1):35.
#   (DOI: https://doi.org/10.1186/s13321-024-00830-3)
# - CDK_pywrapper package (https://pypi.org/project/CDK-pywrapper/)
#
# To implement CDK+RDKIT+Minhash_FP.ipynb, use NP_FP.yml to set up a working Python enviroment

# %%
import pandas as pd
from Calc_fps import Calc_fps

# %%
main_folder = "/data/grd22/AgreementPred_Codes"

# %%
#SMILES to be computed

all_chem = pd.read_csv(f"{main_folder}/Data/All_Compound.csv")[0:50]
all_chem = all_chem[['cmpdname', 'cid', 'canonicalsmiles']]
all_chem
# Out:
# /tmp/ipykernel_476770/728905332.py:1: DtypeWarning: Columns (32,39,40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_chem = pd.read_csv(f"{main_folder}/Data/All_Compound.csv")[0:50]
#                                              cmpdname  cid  \
# 0                                 Acetyl-DL-carnitine    1
# 1     [2-(Acetyloxy)-3-carboxypropyl]trimethylazanium    2
# 2   5,6-Dihydroxycyclohexa-1,3-diene-1-carboxylic ...    3
# 3                                  1-Aminopropan-2-ol    4
# 4                       3-Amino-2-oxopropyl phosphate    5
# 5                                Dinitrochlorobenzene    6
# 6                                      9-Ethyladenine    7
# 7   (2,3,4,5,6-Pentahydroxycyclohexyl) dihydrogen ...    9
# 8                                  1,2-Dichloroethane   11
# 9                         1,2,3,5-Tetrahydroxybenzene   12
# 10                1,8-Diazacyclotetradecane-2,9-dione   16
# ...

# %%
# %%capture
Calc_fps(all_chem, main_folder)
